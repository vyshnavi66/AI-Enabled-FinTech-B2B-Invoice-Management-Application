# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv("H2HBABBA3114.csv")

# %% [markdown]
# # Data Preprocessing

# %%
df.head()
# Out:
#   business_code cust_number       name_customer        clear_date  \
# 0          CA02   140106271  LONGO  corporation  27-02-2020 00:00
# 1          U001   200769623          WAL-MAR co  21-05-2019 00:00
# 2          U001   200769623            WAL-MAR   27-02-2019 00:00
# 3          U001   200706844            WINC llc  29-05-2019 00:00
# 4          U001   200744019           TARG corp               NaN
#
#    buisness_year      doc_id posting_date  document_create_date  \
# 0           2020  2960613801   10-02-2020              20200210
# 1           2019  1929289995   11-05-2019              20190510
# 2           2019  1928799961   17-02-2019              20190215
# 3           2019  1929014762   24-03-2019              20190322
# 4           2020  1930621867   10-03-2020              20200307
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20200210     20200221              CAD            RV
# 1                20190511     20190526              USD            RV
# 2                20190217     20190304              USD            RV
# 3                20190324     20190528              USD            RV
# 4                20200310     20200325              USD            RV
#
#    posting_id  area_business  total_open_amount  baseline_create_date  \
# 0           1            NaN           79736.49              20200211
# 1           1            NaN            9690.20              20190511
# 2           1            NaN           14635.92              20190217
# 3           1            NaN            5410.71              20190324
# 4           1            NaN            5931.36              20200310
#
#   cust_payment_terms    invoice_id  isOpen
# 0               CA10  2.960614e+09       0
# 1               NAH4  1.929290e+09       0
# 2               NAH4  1.928800e+09       0
# 3               NAGD  1.929015e+09       0
# 4               NAA8  1.930622e+09       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  object
#  4   buisness_year           50000 non-null  int64
#  5   doc_id                  50000 non-null  int64
#  6   posting_date            50000 non-null  object
#  7   document_create_date    50000 non-null  int64
#  8   document_create_date.1  50000 non-null  int64
#  9   due_in_date             50000 non-null  int64
#  10  invoice_currency        50000 non-null  object
#  11  document type           50000 non-null  object
#  12  posting_id              50000 non-null  int64
#  13  area_business           0 non-null      float64
#  14  total_open_amount       50000 non-null  float64
#  15  baseline_create_date    50000 non-null  int64
#  16  cust_payment_terms      50000 non-null  object
#  17  invoice_id              49998 non-null  float64
#  18  isOpen                  50000 non-null  int64
# dtypes: float64(3), int64(8), object(8)
# memory usage: 7.2+ MB

# %%
df.isnull().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# area_business             50000
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    2
# isOpen                        0
# dtype: int64

# %% [markdown]
# ## 1. Removing Unwanted Columns

# %%
df.drop('area_business',axis='columns', inplace=True) # droping area_business coloumn because of having null values 
df.drop('document_create_date.1',axis='columns', inplace=True) # droping area_business coloumn because of having null values 
df.drop('posting_id',axis='columns', inplace=True) # droping area_business coloumn because of having null values 
df.drop('document type',axis='columns', inplace=True) # droping area_business coloumn because of having null values

# %% [markdown]
# ## 2. Remove Null Rows

# %%
df_new = df.dropna(how='any', axis=0) # Droping rows with any number of null values

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39998 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   business_code         39998 non-null  object
#  1   cust_number           39998 non-null  object
#  2   name_customer         39998 non-null  object
#  3   clear_date            39998 non-null  object
#  4   buisness_year         39998 non-null  int64
#  5   doc_id                39998 non-null  int64
#  6   posting_date          39998 non-null  object
#  7   document_create_date  39998 non-null  int64
#  8   due_in_date           39998 non-null  int64
#  9   invoice_currency      39998 non-null  object
#  10  total_open_amount     39998 non-null  float64
#  11  baseline_create_date  39998 non-null  int64
#  12  cust_payment_terms    39998 non-null  object
#  13  invoice_id            39998 non-null  float64
#  14  isOpen                39998 non-null  int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 4.9+ MB

# %%
df_new.head()
# Out:
#   business_code cust_number       name_customer        clear_date  \
# 0          CA02   140106271  LONGO  corporation  27-02-2020 00:00
# 1          U001   200769623          WAL-MAR co  21-05-2019 00:00
# 2          U001   200769623            WAL-MAR   27-02-2019 00:00
# 3          U001   200706844            WINC llc  29-05-2019 00:00
# 5          U001      CCU013     KRAFT F systems  27-09-2019 00:00
#
#    buisness_year      doc_id posting_date  document_create_date  due_in_date  \
# 0           2020  2960613801   10-02-2020              20200210     20200221
# 1           2019  1929289995   11-05-2019              20190510     20190526
# 2           2019  1928799961   17-02-2019              20190215     20190304
# 3           2019  1929014762   24-03-2019              20190322     20190528
# 5           2019  1929791025   26-08-2019              20190826     20190826
#
#   invoice_currency  total_open_amount  baseline_create_date  \
# 0              CAD           79736.49              20200211
# 1              USD            9690.20              20190511
# 2              USD           14635.92              20190217
# 3              USD            5410.71              20190324
# 5              USD           14654.80              20190826
#
#   cust_payment_terms    invoice_id  isOpen
# 0               CA10  2.960614e+09       0
# 1               NAH4  1.929290e+09       0
# 2               NAH4  1.928800e+09       0
# 3               NAGD  1.929015e+09       0
# 5               NAX2  1.929791e+09       0

# %% [markdown]
# ## 3. Change Date Format

# %%
import datetime as dt

# %%
#dividing the year, month,date from the number and changing the format

def date_format(date):
    x = str(date)
    year = int(x[0:4])
    month = int(x[4:6])
    day = int(x[6:])
    return dt.datetime(year, month, day)

# %%
df_new['due_in_date'] = pd.to_numeric(df_new['due_in_date'], downcast='integer') #changing the float type to integer

# %%
df_new['baseline_create_date'] = pd.to_numeric(df_new['baseline_create_date'], downcast='integer') #changing float to integer

# %%
df_new['due_in_date'] = df_new['due_in_date'].apply(date_format) #changing the integer to year-month-date format

# %%
df_new['document_create_date'] = df_new['document_create_date'].apply(date_format) #changing the integer to year-month-date form

# %%
df_new['baseline_create_date'] = df_new['baseline_create_date'].apply(date_format) #changing integer type to year-month-date form

# %%
df_new['clear_date']= pd.to_datetime(df_new['clear_date']) #changing object type to datetime format

# %%
df_new.head()
# Out:
#   business_code cust_number       name_customer clear_date  buisness_year  \
# 0          CA02   140106271  LONGO  corporation 2020-02-27           2020
# 1          U001   200769623          WAL-MAR co 2019-05-21           2019
# 2          U001   200769623            WAL-MAR  2019-02-27           2019
# 3          U001   200706844            WINC llc 2019-05-29           2019
# 5          U001      CCU013     KRAFT F systems 2019-09-27           2019
#
#        doc_id posting_date document_create_date due_in_date invoice_currency  \
# 0  2960613801   10-02-2020           2020-02-10  2020-02-21              CAD
# 1  1929289995   11-05-2019           2019-05-10  2019-05-26              USD
# 2  1928799961   17-02-2019           2019-02-15  2019-03-04              USD
# 3  1929014762   24-03-2019           2019-03-22  2019-05-28              USD
# 5  1929791025   26-08-2019           2019-08-26  2019-08-26              USD
#
#    total_open_amount baseline_create_date cust_payment_terms    invoice_id  \
# 0           79736.49           2020-02-11               CA10  2.960614e+09
# 1            9690.20           2019-05-11               NAH4  1.929290e+09
# 2           14635.92           2019-02-17               NAH4  1.928800e+09
# 3            5410.71           2019-03-24               NAGD  1.929015e+09
# 5           14654.80           2019-08-26               NAX2  1.929791e+09
#
#    isOpen
# 0       0
# 1       0
# 2       0
# 3       0
# 5       0

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39998 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   business_code         39998 non-null  object
#  1   cust_number           39998 non-null  object
#  2   name_customer         39998 non-null  object
#  3   clear_date            39998 non-null  datetime64[ns]
#  4   buisness_year         39998 non-null  int64
#  5   doc_id                39998 non-null  int64
#  6   posting_date          39998 non-null  object
#  7   document_create_date  39998 non-null  datetime64[ns]
#  8   due_in_date           39998 non-null  datetime64[ns]
#  9   invoice_currency      39998 non-null  object
#  10  total_open_amount     39998 non-null  float64
#  11  baseline_create_date  39998 non-null  datetime64[ns]
#  12  cust_payment_terms    39998 non-null  object
#  13  invoice_id            39998 non-null  float64
#  14  isOpen                39998 non-null  int64
# dtypes: datetime64[ns](4), float64(2), int64(3), object(6)
# memory usage: 4.9+ MB

# %% [markdown]
# ## 4. Creating the Target Variable

# %%
df_new['delay'] = (df_new['clear_date'] - df_new['due_in_date']).dt.days

# %%
df_new.head()
# Out:
#   business_code cust_number       name_customer clear_date  buisness_year  \
# 0          CA02   140106271  LONGO  corporation 2020-02-27           2020
# 1          U001   200769623          WAL-MAR co 2019-05-21           2019
# 2          U001   200769623            WAL-MAR  2019-02-27           2019
# 3          U001   200706844            WINC llc 2019-05-29           2019
# 5          U001      CCU013     KRAFT F systems 2019-09-27           2019
#
#        doc_id posting_date document_create_date due_in_date invoice_currency  \
# 0  2960613801   10-02-2020           2020-02-10  2020-02-21              CAD
# 1  1929289995   11-05-2019           2019-05-10  2019-05-26              USD
# 2  1928799961   17-02-2019           2019-02-15  2019-03-04              USD
# 3  1929014762   24-03-2019           2019-03-22  2019-05-28              USD
# 5  1929791025   26-08-2019           2019-08-26  2019-08-26              USD
#
#    total_open_amount baseline_create_date cust_payment_terms    invoice_id  \
# 0           79736.49           2020-02-11               CA10  2.960614e+09
# 1            9690.20           2019-05-11               NAH4  1.929290e+09
# 2           14635.92           2019-02-17               NAH4  1.928800e+09
# 3            5410.71           2019-03-24               NAGD  1.929015e+09
# 5           14654.80           2019-08-26               NAX2  1.929791e+09
#
#    isOpen  delay
# 0       0      6
# 1       0     -5
# 2       0     -5
# 3       0      1
# 5       0     32

# %% [markdown]
# ## 5. Train Test Split

# %%
x_train = df_new[df_new['document_create_date'] <= '2020-01-01'].copy() #using Deep copy technique 
x_test = df_new[df_new['document_create_date'] > '2020-01-01'].copy() #using deep copy technique

# %%
print(x_train.shape, x_test.shape)
# Out:
# (35178, 16) (4820, 16)

# %%
x_train.head()
# Out:
#   business_code cust_number    name_customer clear_date  buisness_year  \
# 1          U001   200769623       WAL-MAR co 2019-05-21           2019
# 2          U001   200769623         WAL-MAR  2019-02-27           2019
# 3          U001   200706844         WINC llc 2019-05-29           2019
# 5          U001      CCU013  KRAFT F systems 2019-09-27           2019
# 6          CA02   140106408         WAL-M us 2019-08-03           2019
#
#        doc_id posting_date document_create_date due_in_date invoice_currency  \
# 1  1929289995   11-05-2019           2019-05-10  2019-05-26              USD
# 2  1928799961   17-02-2019           2019-02-15  2019-03-04              USD
# 3  1929014762   24-03-2019           2019-03-22  2019-05-28              USD
# 5  1929791025   26-08-2019           2019-08-26  2019-08-26              USD
# 6  2960529706   18-02-2019           2019-02-18  2019-02-28              CAD
#
#    total_open_amount baseline_create_date cust_payment_terms    invoice_id  \
# 1            9690.20           2019-05-11               NAH4  1.929290e+09
# 2           14635.92           2019-02-17               NAH4  1.928800e+09
# 3            5410.71           2019-03-24               NAGD  1.929015e+09
# 5           14654.80           2019-08-26               NAX2  1.929791e+09
# 6           15440.89           2019-02-18               CA10  2.960530e+09
#
#    isOpen  delay
# 1       0     -5
# 2       0     -5
# 3       0      1
# 5       0     32
# 6       0    156

# %%
x_test.head()
# Out:
#    business_code cust_number        name_customer clear_date  buisness_year  \
# 0           CA02   140106271   LONGO  corporation 2020-02-27           2020
# 13          U001      CCCA02   KRAFT  corporation 2020-02-28           2020
# 17          U001      CCCA02           KRAFT  llc 2020-02-28           2020
# 23          U001   200769556                SHAM  2020-01-14           2020
# 37          U001   200772670  ASSOCIAT foundation 2020-04-02           2020
#
#         doc_id posting_date document_create_date due_in_date invoice_currency  \
# 0   2960613801   10-02-2020           2020-02-10  2020-02-21              CAD
# 13  1930384514   19-01-2020           2020-01-10  2020-02-23              USD
# 17  1930351602   05-01-2020           2020-01-03  2020-02-09              USD
# 23  1930366322   09-01-2020           2020-01-07  2020-01-24              USD
# 37  1930429974   22-01-2020           2020-01-22  2020-02-06              USD
#
#     total_open_amount baseline_create_date cust_payment_terms    invoice_id  \
# 0            79736.49           2020-02-11               CA10  2.960614e+09
# 13           62504.40           2020-01-19               NAG2  1.930385e+09
# 17           18666.08           2020-01-05               NAG2  1.930352e+09
# 23           25477.58           2020-01-09               NAA8  1.930366e+09
# 37           45936.96           2020-01-22               NAU5  1.930430e+09
#
#     isOpen  delay
# 0        0      6
# 13       0      5
# 17       0     19
# 23       0    -10
# 37       0     56

# %%
x_train.describe()
# Out:
#        buisness_year        doc_id  total_open_amount    invoice_id   isOpen  \
# count   35178.000000  3.517800e+04       3.517800e+04  3.517800e+04  35178.0
# mean     2019.008272  2.012320e+09       3.212665e+04  2.012320e+09      0.0
# std         0.090576  2.785325e+08       4.020220e+04  2.785325e+08      0.0
# min      2019.000000  1.928502e+09       4.380000e+00  1.928502e+09      0.0
# 25%      2019.000000  1.929102e+09       4.742550e+03  1.929102e+09      0.0
# 50%      2019.000000  1.929614e+09       1.718546e+04  1.929614e+09      0.0
# 75%      2019.000000  1.930032e+09       4.659104e+04  1.930032e+09      0.0
# max      2020.000000  2.960605e+09       1.673456e+06  2.960605e+09      0.0
#
#               delay
# count  35178.000000
# mean      -5.612229
# std       88.960661
# min     -334.000000
# 25%       -5.000000
# 50%        0.000000
# 75%        4.000000
# max      321.000000

# %% [markdown]
# # EDA and Feature Engineering

# %%
import sweetviz as sv

# %%
report = sv.analyze(x_train)

# %%
report.show_html('report.html')
# Out:
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
from autoviz.AutoViz_Class import AutoViz_Class 
AV = AutoViz_Class()
# Out:
# Imported AutoViz_Class version: 0.0.81. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Note: verbose=0 or 1 generates charts and displays them in your local Jupyter notebook.
#       verbose=2 saves plots in your local machine under AutoViz_Plots directory and does not display charts.

# %%
dataviz = AV.AutoViz("H2HBABBA3114.csv")
# Out:
# Shape of your Data Set: (50000, 19)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  5
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  2
#     Number of Numeric-Boolean Columns =  2
#     Number of Discrete String Columns =  5
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  2
#     19 Predictors classified...
#         This does not include the Target column(s)
#         7 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 3
# Time to run AutoViz (in seconds) = 17.698
#
#  ###################### VISUALIZATION Completed ########################

# %% [markdown]
# ### 1. Univariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plot = dict(x_train['business_code'].value_counts())
print(plot)

x_train['business_code1'] = x_train['business_code'].map(plot) #added new column to data set
x_test['business_code1'] = x_test['business_code'].map(plot) #added new column to data set
# Out:
# {'U001': 31805, 'CA02': 2792, 'U013': 440, 'U002': 130, 'U005': 9, 'U007': 2}

# %% [markdown]
# 1)From above we can see that there was very few data with U002, U005, U007.
# 2)The business codes(U002, U005, U007) can be dropped or else we can merge them into one

# %%
sns.distplot(x_train['business_code1']) #distribution plot of business codes
# Out:
# <AxesSubplot:xlabel='business_code1', ylabel='Density'>

# %%
x_train = x_train.replace(['U002', 'U005', 'U007'], 'other') #replace U002, U005, U007 with other(merging)
x_test = x_test.replace(['U002', 'U005', 'U007'], 'other') #replace U002, U005, U007 with other(merging)

# %%
graph = dict(x_train['cust_number'].value_counts())
print(graph)

x_train['cust_number1'] = x_train['cust_number'].map(graph)
# Out:
# {'200769623': 8471, '200726979': 1375, '200762301': 1135, '200759878': 1013, '200794332': 911, '200744019': 755, '200772670': 627, '200705742': 599, '200707822': 520, 'CCU013': 498, '200418007': 436, '140104409': 410, 'CCCA02': 391, '140106408': 374, '200780383': 368, '100031704': 335, '200803720': 329, '140104429': 319, '200936373': 303, '200706844': 284, '200761734': 281, '200416837': 276, '200353024': 273, '200148860': 266, '200799367': 257, '200704858': 255, '200230690': 251, '200793568': 235, '140105686': 231, '200020431': 222, '140104440': 215, '200772595': 206, '200974851': 203, '200729942': 185, '200739534': 175, '200782001': 166, '200704045': 161, '200714710': 160, '200900909': 152, '200592182': 141, '200752302': 138, '200781803': 137, '200777735': 135, '200792293': 135, '200792734': 132, '200764795': 131, '140104423': 130, '200729290': 128, '140105847': 126, '200718130': 123, '200763814': 121, '200776463': 120, '200152991': 117, '200331749': 116, '200778870': 103, '200126819': 101, '200743123': 99, 'CCU002': 98, '200756072': 97, '200466603': 96, '200741174': 94, '200782669': 93, '200881076': 89, '140104340': 86, '200705372': 86, '200707005': 84, '140106181': 84, '200786288': 82, '200705089': 82, '200739006': 80, '200750051': 80, '200820380': 78, '200722444': 78, '200700919': 77, '200779906': 77, '200337148': 75, '200790107': 74, '200455322': 73, '200793513': 72, '100001196': 72, '200780825': 71, '200078795': 71, '200711029': 70, '200732755': 69, '200712105': 69, '200920735': 68, '200434439': 68, '200762950': 66, '200795490': 65, '200771157': 65, '200797452': 65, '200875006': 63, '200748108': 59, '140104249': 59, '200915438': 58, '200290370': 57, '140104225': 57, '200712187': 57, '200785971': 55, '200793830': 54, '200742791': 52, '200721222': 51, '140105785': 50, '200736337': 50, '200357714': 50, '200749225': 50, '200793088': 50, '200778355': 49, '200561861': 48, '200743996': 48, '140104240': 48, '200743129': 48, '200749782': 47, '200707741': 46, '200747369': 44, '200712102': 43, '200965912': 43, '200978592': 42, '200571849': 41, '200526831': 40, '200719300': 40, '200759082': 40, '200229974': 40, '200895843': 40, '200799538': 40, '200769369': 39, '200725421': 38, '140104472': 38, '200555117': 38, '200980828': 36, '200865666': 36, '200943275': 36, '200797984': 35, '200729828': 35, '200501669': 34, '100036066': 34, '200789077': 34, 'CC6600': 34, '100021540': 33, '200407025': 33, '200696090': 33, '200029010': 32, '200773364': 32, 'CCU001': 32, '200275115': 30, '100030964': 30, '200723794': 30, '200458131': 30, '200742521': 30, '140106293': 30, '200770567': 30, '200763152': 29, '200708411': 29, '200701314': 29, '200735528': 29, '200622385': 29, '200792283': 28, '200799180': 28, '200778998': 28, '200763229': 27, '100009932': 27, '200580232': 27, '100043892': 27, '200519201': 27, '140103335': 26, '200942148': 26, '200435191': 26, '140106372': 26, '200396637': 26, '100030194': 25, '200806580': 25, '200783734': 25, '200769556': 25, '100043936': 24, '200799342': 24, '140104229': 24, 'CC6000': 24, '200149567': 24, '200186937': 24, '200833713': 23, '140104285': 23, '140104392': 23, '200775094': 23, '200724999': 22, '200779051': 21, '200493614': 21, '140103480': 21, '200765011': 21, '140103409': 21, '200886415': 21, 'CC3620': 20, '200508557': 20, '200790710': 19, '100006311': 19, 'CC6050': 19, '200763489': 19, '200002965': 19, '200956366': 19, '200755701': 19, '100000222': 19, '200779719': 19, '200760666': 18, '200754278': 18, '200720238': 18, '200719526': 18, '140103278': 18, '140142846': 17, '200515231': 17, '200439158': 17, '200014556': 17, '140103592': 17, '200486270': 17, '200609331': 17, '200793122': 17, '200782772': 16, '140105508': 16, '100012638': 16, '200076137': 16, '200847305': 16, '100036039': 16, '200816950': 16, '100015557': 15, '200701040': 15, '200457993': 15, '200424504': 15, '100004536': 15, '200891601': 15, '200741831': 15, '140106231': 15, '200697207': 14, '140104552': 14, '140118172': 14, '100012991': 13, '2 ...

# %%
sns.distplot(x_train['cust_number1']) #distribution of customers
# Out:
# <AxesSubplot:xlabel='cust_number1', ylabel='Density'>

# %%
graph1 = dict(x_test['cust_number'].value_counts())
x_test['cust_number1'] = x_test['cust_number'].map(graph1)

# %% [markdown]
# ### 2. Bivariate Analysis

# %%
plot1 = x_train.groupby(['business_code'], axis=0, as_index=False)['delay'].mean()

# %%
sns.barplot(x="business_code", y="delay",data=plot1)
# Out:
# <AxesSubplot:xlabel='business_code', ylabel='delay'>

# %%
plot2 = pd.DataFrame(x_train.groupby(['cust_number'], axis=0, as_index=False)['delay'].mean())
plt.figure(figsize=(20,6))
sns.barplot(x="cust_number", y="delay",data=plot2) #customer vs the delay
# Out:
# <AxesSubplot:xlabel='cust_number', ylabel='delay'>

# %%
plot4 = pd.DataFrame(x_train.groupby(['cust_payment_terms'], axis=0, as_index=False)['delay'].mean())
plt.figure(figsize=(20,6))
sns.barplot(x="cust_payment_terms", y="delay",data=plot4)
# Out:
# <AxesSubplot:xlabel='cust_payment_terms', ylabel='delay'>

# %%
plot3 = pd.DataFrame(x_train.groupby(['buisness_year'], axis = 0, as_index=False)['total_open_amount'].mean())
sns.barplot(x='buisness_year', y='total_open_amount', data=plot3) # average finance happend in the partiualar year
# Out:
# <AxesSubplot:xlabel='buisness_year', ylabel='total_open_amount'>

# %%
sns.distplot(x_train['total_open_amount']) #distribution of the amount(we can see the distribution is right skewed)
# Out:
# <AxesSubplot:xlabel='total_open_amount', ylabel='Density'>

# %%
# The graph is Right Skewed: log transformation is needed.
'''
In general, for right-skewed data, the log-transformation may make it either right-or left-skewed. If the original 
data does follow a log-normal distribution, the log-transformed data will follow or approximately follow the normal 
distribution.
'''
import numpy as np
def Transform(x):
    return np.log(x)

x_train['total_open_amount'] = x_train['total_open_amount'].apply(Transform)
x_test['total_open_amount'] = x_test['total_open_amount'].apply(Transform)

# %%
sns.distplot(x_train['total_open_amount']) #distribution of the amount(we can see the distribution is right skewed)
# Out:
# <AxesSubplot:xlabel='total_open_amount', ylabel='Density'>

# %%
x_train.head()
# Out:
#   business_code cust_number    name_customer clear_date  buisness_year  \
# 1          U001   200769623       WAL-MAR co 2019-05-21           2019
# 2          U001   200769623         WAL-MAR  2019-02-27           2019
# 3          U001   200706844         WINC llc 2019-05-29           2019
# 5          U001      CCU013  KRAFT F systems 2019-09-27           2019
# 6          CA02   140106408         WAL-M us 2019-08-03           2019
#
#        doc_id posting_date document_create_date due_in_date invoice_currency  \
# 1  1929289995   11-05-2019           2019-05-10  2019-05-26              USD
# 2  1928799961   17-02-2019           2019-02-15  2019-03-04              USD
# 3  1929014762   24-03-2019           2019-03-22  2019-05-28              USD
# 5  1929791025   26-08-2019           2019-08-26  2019-08-26              USD
# 6  2960529706   18-02-2019           2019-02-18  2019-02-28              CAD
#
#    total_open_amount baseline_create_date cust_payment_terms    invoice_id  \
# 1           9.178870           2019-05-11               NAH4  1.929290e+09
# 2           9.591234           2019-02-17               NAH4  1.928800e+09
# 3           8.596136           2019-03-24               NAGD  1.929015e+09
# 5           9.592523           2019-08-26               NAX2  1.929791e+09
# 6           9.644774           2019-02-18               CA10  2.960530e+09
#
#    isOpen  delay  business_code1  cust_number1
# 1       0     -5           31805          8471
# 2       0     -5           31805          8471
# 3       0      1           31805           284
# 5       0     32           31805           498
# 6       0    156            2792           374

# %% [markdown]
# ## 3. Creating new features

# %%
#creating new columns in training data
x_train['year'] = x_train['document_create_date'].dt.year
x_train['month'] = x_train['document_create_date'].dt.month
x_train['day'] = x_train['document_create_date'].dt.day
x_train['week'] = x_train['document_create_date'].dt.week
x_train['which_day'] = x_train['document_create_date'].dt.dayofweek
x_train['quarter'] = x_train['document_create_date'].dt.quarter

# %%
#creating new columns in testing data
x_test['year'] = x_test['document_create_date'].dt.year
x_test['month'] = x_test['document_create_date'].dt.month
x_test['day'] = x_test['document_create_date'].dt.day
x_test['week'] = x_test['document_create_date'].dt.week
x_test['which_day'] = x_test['document_create_date'].dt.dayofweek
x_test['quarter'] = x_test['document_create_date'].dt.quarter

# %%
x_train.head()
# Out:
#   business_code cust_number    name_customer clear_date  buisness_year  \
# 1          U001   200769623       WAL-MAR co 2019-05-21           2019
# 2          U001   200769623         WAL-MAR  2019-02-27           2019
# 3          U001   200706844         WINC llc 2019-05-29           2019
# 5          U001      CCU013  KRAFT F systems 2019-09-27           2019
# 6          CA02   140106408         WAL-M us 2019-08-03           2019
#
#        doc_id posting_date document_create_date due_in_date invoice_currency  \
# 1  1929289995   11-05-2019           2019-05-10  2019-05-26              USD
# 2  1928799961   17-02-2019           2019-02-15  2019-03-04              USD
# 3  1929014762   24-03-2019           2019-03-22  2019-05-28              USD
# 5  1929791025   26-08-2019           2019-08-26  2019-08-26              USD
# 6  2960529706   18-02-2019           2019-02-18  2019-02-28              CAD
#
#    ...  isOpen delay business_code1  cust_number1  year  month  day  week  \
# 1  ...       0    -5          31805          8471  2019      5   10    19
# 2  ...       0    -5          31805          8471  2019      2   15     7
# 3  ...       0     1          31805           284  2019      3   22    12
# 5  ...       0    32          31805           498  2019      8   26    35
# 6  ...       0   156           2792           374  2019      2   18     8
#
#    which_day  quarter
# 1          4        2
# 2          4        1
# 3          4        1
# 5          0        3
# 6          0        1
#
# [5 rows x 24 columns]

# %%
x_test.head()
# Out:
#    business_code cust_number        name_customer clear_date  buisness_year  \
# 0           CA02   140106271   LONGO  corporation 2020-02-27           2020
# 13          U001      CCCA02   KRAFT  corporation 2020-02-28           2020
# 17          U001      CCCA02           KRAFT  llc 2020-02-28           2020
# 23          U001   200769556                SHAM  2020-01-14           2020
# 37          U001   200772670  ASSOCIAT foundation 2020-04-02           2020
#
#         doc_id posting_date document_create_date due_in_date invoice_currency  \
# 0   2960613801   10-02-2020           2020-02-10  2020-02-21              CAD
# 13  1930384514   19-01-2020           2020-01-10  2020-02-23              USD
# 17  1930351602   05-01-2020           2020-01-03  2020-02-09              USD
# 23  1930366322   09-01-2020           2020-01-07  2020-01-24              USD
# 37  1930429974   22-01-2020           2020-01-22  2020-02-06              USD
#
#     ...    invoice_id isOpen delay  business_code1  year  month  day  week  \
# 0   ...  2.960614e+09      0     6            2792  2020      2   10     7
# 13  ...  1.930385e+09      0     5           31805  2020      1   10     2
# 17  ...  1.930352e+09      0    19           31805  2020      1    3     1
# 23  ...  1.930366e+09      0   -10           31805  2020      1    7     2
# 37  ...  1.930430e+09      0    56           31805  2020      1   22     4
#
#     which_day  quarter
# 0           0        1
# 13          4        1
# 17          4        1
# 23          1        1
# 37          2        1
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 4. Encoding the Currency column

# %%
invoice_curr = {'USD': 1, 'CAD': 0}
x_train['invoice_currency'] = x_train['invoice_currency'].map(invoice_curr)
x_test['invoice_currency'] = x_test['invoice_currency'].map(invoice_curr)

# %%
buisness = pd.get_dummies(x_train['business_code'])
buisness1 = pd.get_dummies(x_test['business_code'])

# %%
x_train = pd.concat([x_train, buisness], axis=1)
x_test = pd.concat([x_test, buisness1], axis=1)

# %%
X_train=x_train.drop(['business_code','cust_number', 'name_customer', 'doc_id', 'cust_payment_terms', 'invoice_id'], axis = 1)

X_test = x_test.drop(['business_code','cust_number', 'name_customer', 'doc_id', 'cust_payment_terms', 'invoice_id'], axis = 1)

# %%
x_train.head()
# Out:
#   business_code cust_number    name_customer clear_date  buisness_year  \
# 1          U001   200769623       WAL-MAR co 2019-05-21           2019
# 2          U001   200769623         WAL-MAR  2019-02-27           2019
# 3          U001   200706844         WINC llc 2019-05-29           2019
# 5          U001      CCU013  KRAFT F systems 2019-09-27           2019
# 6          CA02   140106408         WAL-M us 2019-08-03           2019
#
#        doc_id posting_date document_create_date due_in_date  invoice_currency  \
# 1  1929289995   11-05-2019           2019-05-10  2019-05-26                 1
# 2  1928799961   17-02-2019           2019-02-15  2019-03-04                 1
# 3  1929014762   24-03-2019           2019-03-22  2019-05-28                 1
# 5  1929791025   26-08-2019           2019-08-26  2019-08-26                 1
# 6  2960529706   18-02-2019           2019-02-18  2019-02-28                 0
#
#    ...  year month day  week  which_day  quarter  CA02  U001  U013  other
# 1  ...  2019     5  10    19          4        2     0     1     0      0
# 2  ...  2019     2  15     7          4        1     0     1     0      0
# 3  ...  2019     3  22    12          4        1     0     1     0      0
# 5  ...  2019     8  26    35          0        3     0     1     0      0
# 6  ...  2019     2  18     8          0        1     1     0     0      0
#
# [5 rows x 28 columns]

# %%
X_train.head()
# Out:
#   clear_date  buisness_year posting_date document_create_date due_in_date  \
# 1 2019-05-21           2019   11-05-2019           2019-05-10  2019-05-26
# 2 2019-02-27           2019   17-02-2019           2019-02-15  2019-03-04
# 3 2019-05-29           2019   24-03-2019           2019-03-22  2019-05-28
# 5 2019-09-27           2019   26-08-2019           2019-08-26  2019-08-26
# 6 2019-08-03           2019   18-02-2019           2019-02-18  2019-02-28
#
#    invoice_currency  total_open_amount baseline_create_date  isOpen  delay  \
# 1                 1           9.178870           2019-05-11       0     -5
# 2                 1           9.591234           2019-02-17       0     -5
# 3                 1           8.596136           2019-03-24       0      1
# 5                 1           9.592523           2019-08-26       0     32
# 6                 0           9.644774           2019-02-18       0    156
#
#    ...  year  month  day  week  which_day  quarter  CA02  U001  U013  other
# 1  ...  2019      5   10    19          4        2     0     1     0      0
# 2  ...  2019      2   15     7          4        1     0     1     0      0
# 3  ...  2019      3   22    12          4        1     0     1     0      0
# 5  ...  2019      8   26    35          0        3     0     1     0      0
# 6  ...  2019      2   18     8          0        1     1     0     0      0
#
# [5 rows x 22 columns]

# %%
#creating new feature of expected delay
X_train['clear_date']= pd.to_datetime(X_train['clear_date']) 

X_train['expected_delay'] = (X_train['due_in_date'] - X_train['baseline_create_date']).dt.days

# %%
X_test['clear_date']= pd.to_datetime(X_test['clear_date']) 

X_test['expected_delay'] = (X_test['due_in_date'] - X_test['baseline_create_date']).dt.days

# %%
X_train.head()
# Out:
#   clear_date  buisness_year posting_date document_create_date due_in_date  \
# 1 2019-05-21           2019   11-05-2019           2019-05-10  2019-05-26
# 2 2019-02-27           2019   17-02-2019           2019-02-15  2019-03-04
# 3 2019-05-29           2019   24-03-2019           2019-03-22  2019-05-28
# 5 2019-09-27           2019   26-08-2019           2019-08-26  2019-08-26
# 6 2019-08-03           2019   18-02-2019           2019-02-18  2019-02-28
#
#    invoice_currency  total_open_amount baseline_create_date  isOpen  delay  \
# 1                 1           9.178870           2019-05-11       0     -5
# 2                 1           9.591234           2019-02-17       0     -5
# 3                 1           8.596136           2019-03-24       0      1
# 5                 1           9.592523           2019-08-26       0     32
# 6                 0           9.644774           2019-02-18       0    156
#
#    ...  month  day  week  which_day  quarter  CA02  U001  U013  other  \
# 1  ...      5   10    19          4        2     0     1     0      0
# 2  ...      2   15     7          4        1     0     1     0      0
# 3  ...      3   22    12          4        1     0     1     0      0
# 5  ...      8   26    35          0        3     0     1     0      0
# 6  ...      2   18     8          0        1     1     0     0      0
#
#    expected_delay
# 1              15
# 2              15
# 3              65
# 5               0
# 6              10
#
# [5 rows x 23 columns]

# %%
plt.figure(figsize=(15,15))
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
X_train = X_train.drop(['isOpen'], axis =1)
X_test = X_test.drop(['isOpen'], axis =1)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
X_train = X_train.drop(['clear_date', 'posting_date', 'document_create_date', 'baseline_create_date','due_in_date'], axis = 1)

# %%
X_test = X_test.drop(['clear_date', 'posting_date', 'document_create_date', 'baseline_create_date','due_in_date'], axis = 1)

# %%
X_train = X_train.drop(['CA02', 'week', 'U001'], axis = 1)

X_test = X_test.drop(['CA02', 'week', 'U001'], axis = 1)

# %%
y_train = X_train['delay']
X_train = X_train.drop(['delay'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'delay'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-fa1200bb33c6> in <module>
# ----> 1 y_train = X_train['delay']
#       2 X_train = X_train.drop(['delay'], axis = 1)
#
# ~\miniconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~\miniconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'delay'

# %%
y_test = X_test['delay']
X_test = X_test.drop(['delay'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'delay'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-69614c7979a3> in <module>
# ----> 1 y_test = X_test['delay']
#       2 X_test = X_test.drop(['delay'], axis = 1)
#
# ~\miniconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~\miniconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'delay'

# %%
X_train.columns
# Out:
# Index(['buisness_year', 'invoice_currency', 'total_open_amount',
#        'business_code1', 'year', 'month', 'day', 'which_day', 'quarter',
#        'U013', 'other', 'expected_delay'],
#       dtype='object')

# %%
X_test.columns
# Out:
# Index(['buisness_year', 'invoice_currency', 'total_open_amount',
#        'business_code1', 'year', 'month', 'day', 'which_day', 'quarter',
#        'U013', 'other', 'expected_delay'],
#       dtype='object')

# %% [markdown]
# # Regression ML Model

# %% [markdown]
# ## 1. Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
reg1 = LinearRegression()

# %%
reg1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: ', reg1.coef_)
# Out:
# Coefficients:  [ 9.95209625e+01 -2.33137583e+03  1.32789253e+00  8.02648496e-02
#  -1.21694607e+02 -8.86594263e+00  2.96634573e-01  5.23733687e-01
#  -4.10813765e+00  2.53760133e+03  2.55093121e+03 -6.83216373e-01]

# %%
y_pred = reg1.predict(X_test)

# %%
accuracy1 = round(reg1.score(X_train, y_train)*100,2)
print(round(accuracy1, 2), '%')
# Out:
# 15.29 %

# %%
accuracy1 = round(reg1.score(X_test, y_test)*100,2)
print(round(accuracy1, 2), '%')
# Out:
# -7.26 %

# %% [markdown]
# ## 2. Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
reg2 = Lasso(alpha=0.1)

# %%
reg2.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
y_pred1 = reg2.predict(X_test)

# %%
print('Coefficients: ', reg2.coef_)
# Out:
# Coefficients:  [ 8.54397191e+01  4.61288566e+00  1.27673866e+00 -2.96715103e-04
#  -1.05481880e+02 -8.78915758e+00  3.38422946e-01  5.18052317e-01
#  -3.95945151e+00  2.40339901e+00 -0.00000000e+00 -6.57502052e-01]

# %%
accuracy2 = round(reg2.score(X_train, y_train)*100,2)
print(round(accuracy2, 2), '%')
# Out:
# 15.24 %

# %%
accuracy2 = round(reg2.score(X_test, y_test)*100,2)
print(round(accuracy2, 2), '%')
# Out:
# -5.79 %

# %% [markdown]
# ## 3. Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
reg3 = Ridge(alpha=1.0)

# %%
reg3.fit(Xtrain, ytrain)
# Out:
# Ridge()

# %%
y_pred2 = reg3.predict(Xtest)

# %%
accuracy3 = round(reg3.score(Xtrain, ytrain)*100,2)
print(round(accuracy3, 2), '%')
# Out:
# 15.4 %

# %%
accuracy3 = round(reg3.score(Xtest, ytest)*100,2)
print(round(accuracy3, 2), '%')
# Out:
# 14.86 %

# %% [markdown]
# ## 4. Elastic Net

# %%
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import GridSearchCV
import numpy as np

# %%
reg4=ElasticNet(normalize=True)
search=GridSearchCV(estimator=reg4,param_grid={'alpha':np.logspace(-5,2,8),'l1_ratio':[.2,.4,.6,.8]},scoring='neg_mean_squared_error',n_jobs=1,refit=True,cv=10)

# %%
search.fit(Xtrain,ytrain)
print(search.best_params_)
abs(search.best_score_)
# Out:
# {'alpha': 1e-05, 'l1_ratio': 0.8}
# 6777.516648844166

# %%
elastic=ElasticNet(normalize=True,alpha=1e-5,l1_ratio=0.8)

# %%
elastic.fit(Xtrain,ytrain)
# Out:
# ElasticNet(alpha=1e-05, l1_ratio=0.8, normalize=True)

# %%
y_pred3 = elastic.predict(Xtest)

# %%
accuracy4 = round(elastic.score(Xtrain, ytrain)*100,2)
print(round(accuracy4, 2), '%')
# Out:
# 15.28 %

# %%
accuracy4 = round(elastic.score(Xtest, ytest)*100,2)
print(round(accuracy4, 2), '%')
# Out:
# 14.67 %

# %% [markdown]
# ## 5. Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
reg5 = DecisionTreeRegressor( )

# %%
reg5.fit(Xtrain, ytrain)
# Out:
# DecisionTreeRegressor()

# %%
y_pred4 = reg5.predict(Xtest)

# %%
accuracy5 = round(reg5.score(Xtrain, ytrain)*100,2)
print(round(accuracy5, 2), '%')
# Out:
# 99.95 %

# %%
accuracy5 = round(reg5.score(Xtest, ytest)*100,2)
print(round(accuracy5, 2), '%')
# Out:
# 19.08 %

# %% [markdown]
# ## 6. Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
reg6 = RandomForestRegressor(n_estimators=500, random_state = 42)

# %%
reg6.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=500, random_state=42)

# %%
y_pred5 = reg6.predict(X_test)

# %%
accuracy6 = round(reg6.score(X_train, y_train)*100,2)
print(round(accuracy6, 2), '%')
# Out:
# 93.86 %

# %%
accuracy6 = round(reg6.score(X_test, y_test)*100,2)
print(round(accuracy6, 2), '%')
# Out:
# 12.79 %

# %% [markdown]
# From above acuracy scores we can see that the random forest performed better compared to reamining regression models.

# %% [markdown]
# ## Hyperparameter Optimization

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 700, num = 10)] # Number of trees in random forest
max_features = ['auto', 'sqrt'] # Number of features to consider at every split
max_depth = [int(x) for x in np.linspace(10, 55, num = 11)] # Maximum number of levels in tree
max_depth.append(None)
min_samples_split = [2, 5, 10] # Minimum number of samples required to split a node
min_samples_leaf = [1, 2, 4] # Minimum number of samples required at each leaf node
bootstrap = [True, False] # Method of selecting samples for training each tree
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
print(random_grid)
# Out:
# {'n_estimators': [200, 255, 311, 366, 422, 477, 533, 588, 644, 700], 'max_features': ['auto', 'sqrt'], 'max_depth': [10, 14, 19, 23, 28, 32, 37, 41, 46, 50, 55, None], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4], 'bootstrap': [True, False]}

# %%
# First create the base model to tune
regressor = RandomForestRegressor() # Random search of parameters, using 3 fold cross validation, 
rf_random = RandomizedSearchCV(estimator = regressor, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-cb216f13cbae> in <module>
#       1 # First create the base model to tune
#       2 regressor = RandomForestRegressor() # Random search of parameters, using 3 fold cross validation,
# ----> 3 rf_random = RandomizedSearchCV(estimator = regressor, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
#
# NameError: name 'random_grid' is not defined

# %%
rf_random.fit(Xtrain, ytrain) # Fit the random search model
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# RandomizedSearchCV(cv=3, estimator=RandomForestRegressor(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [10, 14, 19, 23, 28, 32,
#                                                       37, 41, 46, 50, 55,
#                                                       None],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [200, 255, 311, 366,
#                                                          422, 477, 533, 588,
#                                                          644, 700]},
#                    random_state=42, verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 311,
#  'min_samples_split': 2,
#  'min_samples_leaf': 4,
#  'max_features': 'auto',
#  'max_depth': 23,
#  'bootstrap': True}

# %%
reg6 = RandomForestRegressor(n_estimators = 311, min_samples_split = 2, min_samples_leaf = 4, max_features = 'auto',
                                      max_depth = 23, bootstrap = True)

# %%
reg6.fit(Xtrain, ytrain)
# Out:
# RandomForestRegressor(max_depth=23, min_samples_leaf=4, n_estimators=311)

# %%
accuracy6 = round(reg6.score(Xtrain, ytrain)*100,2)
print(round(accuracy6, 2), '%')
# Out:
# 76.84 %

# %%
accuracy6 = round(reg6.score(Xtest, ytest)*100,2)
print(round(accuracy6, 2), '%')
# Out:
# 55.0 %

# %%
data = reg6.predict(Xtest)
data[0:10]
# Out:
# array([  -2.30526941,   10.01207595,   13.46871797,    1.44929171,
#          -1.36320591,   -9.0780158 ,   90.59466458,   -5.12909269,
#          -1.59036103, -199.76640012])

# %%
def Prediction(x):
    temp = []
    for i in list(x):
        if i < 0:
            temp.append("Payment done before due date.")
        elif i<10:
            temp.append("Payment done before 10 days after due date")
        elif i > 15:
            temp.append("Payment done 15 days after due date.")
        elif i > 30:
            temp.append("Payment done 30 days after due date.")
        else:
            temp.append("Payment done much after due date.")
    return temp

func = Prediction(data)
bucket = pd.DataFrame()
bucket['Predictions'] = data
bucket['Bucket_list'] = func
bucket.head()
# Out:
#    Predictions                                 Bucket_list
# 0    -2.305269               Payment done before due date.
# 1    10.012076           Payment done much after due date.
# 2    13.468718           Payment done much after due date.
# 3     1.449292  Payment done before 10 days after due date
# 4    -1.363206               Payment done before due date.

# %% [markdown]
# ## 7. Artificial Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
Xtrain.shape
# Out:
# (28142, 13)

# %%
ytrain.shape
# Out:
# (28142,)

# %%
ytrain.head()
# Out:
# 27219     4
# 40895    33
# 36100     0
# 36290     1
# 19355    19
# Name: delay, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_nn_train = sc.fit_transform(Xtrain)
X_nn_test = sc.transform(Xtest)

# %%
ytrain.shape
# Out:
# (28142,)

# %%
n_features = Xtrain.shape[1]

# %%
model = Sequential()
model.add(Dense(20, input_dim=n_features, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='linear'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_41 (Dense)             (None, 20)                280
# _________________________________________________________________
# dense_42 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_43 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 501
# Trainable params: 501
# Non-trainable params: 0
# _________________________________________________________________

# %%
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

# %%
model.compile(loss='mse', optimizer='adam',metrics=["accuracy"])

# %%
nn = model.fit(Xtrain, ytrain, epochs=30, batch_size=32, verbose=2)
# Out:
# Epoch 1/30
#  - 1s - loss: 15443.8826 - acc: 0.0060
# Epoch 2/30
#  - 1s - loss: 12765.1282 - acc: 0.0059
# Epoch 3/30
#  - 1s - loss: 25434.3915 - acc: 0.0074
# Epoch 4/30
#  - 1s - loss: 9671.2019 - acc: 0.0071
# Epoch 5/30
#  - 1s - loss: 37312.2109 - acc: 0.0064
# Epoch 6/30
#  - 2s - loss: 9926.6001 - acc: 0.0080
# Epoch 7/30
#  - 1s - loss: 14358.4056 - acc: 0.0069
# Epoch 8/30
#  - 1s - loss: 9251.3375 - acc: 0.0060
# Epoch 9/30
#  - 1s - loss: 16525.7989 - acc: 0.0072
# Epoch 10/30
#  - 1s - loss: 16775.6473 - acc: 0.0060
# Epoch 11/30
#  - 2s - loss: 9749.5986 - acc: 0.0068
# Epoch 12/30
#  - 1s - loss: 11460.8624 - acc: 0.0058
# Epoch 13/30
#  - 1s - loss: 11812.9918 - acc: 0.0061
# Epoch 14/30
#  - 1s - loss: 11634.1696 - acc: 0.0064
# Epoch 15/30
#  - 1s - loss: 10716.8406 - acc: 0.0066
# Epoch 16/30
#  - 1s - loss: 34075.6944 - acc: 0.0059
# Epoch 17/30
#  - 1s - loss: 8909.2938 - acc: 0.0073
# Epoch 18/30
#  - 1s - loss: 19472.3668 - acc: 0.0067
# Epoch 19/30
#  - 1s - loss: 8917.7686 - acc: 0.0062
# Epoch 20/30
#  - 1s - loss: 23398.7874 - acc: 0.0073
# Epoch 21/30
#  - 1s - loss: 14043.1196 - acc: 0.0069
# Epoch 22/30
#  - 1s - loss: 8557.2860 - acc: 0.0075
# Epoch 23/30
#  - 1s - loss: 19410.6336 - acc: 0.0071
# Epoch 24/30
#  - 1s - loss: 13714.5419 - acc: 0.0071
# Epoch 25/30
#  - 1s - loss: 15900.9562 - acc: 0.0072
# Epoch 26/30
#  - 1s - loss: 8604.6775 - acc: 0.0080
# Epoch 27/30
#  - 1s - loss: 20664.6949 - acc: 0.0071
# Epoch 28/30
#  - 1s - loss: 11340.5165 - acc: 0.0086
# Epoch 29/30
#  - 1s - loss: 11132.0788 - acc: 0.0081
# Epoch 30/30
#  - 1s - loss: 8742.6547 - acc: 0.0076

# %%
yhat = model.predict(Xtest)
